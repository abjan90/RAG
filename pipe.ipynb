# %%
from langchain_core.documents import Document
docs = Document(
    page_content = "Hero maki" ,
    metadata = {
        "source" : "example.txt",
        "pages" : 2 ,
        "author" : "Abhiujan"
    }
)

# %%
from langchain_community.document_loaders import TextLoader

load = TextLoader("textfile/text.txt" , encoding="utf-8")
docs = load.load()
print(docs)
# Out:
# [Document(metadata={'source': 'textfile/text.txt'}, page_content='\nWastewater is used water that has been affected by human activities such as domestic, industrial, and agricultural use. It typically contains dissolved or suspended contaminants and must be treated before being released into the environment.\nWastewater treatment is the process of removing contaminants from wastewater to produce water that is safe for discharge or reuse. The process generally includes physical, biological, and chemical treatment stages.\nThe primary goal of wastewater management is to protect public health and the environment. Proper treatment reduces water pollution and helps maintain ecosystem balance.\nCommon sources of wastewater include households, factories, hospitals, and stormwater runoff. Each source contributes different types of pollutants that require specific treatment methods.\n')]

# %%
from langchain_community.document_loaders import DirectoryLoader

load = DirectoryLoader(
    "textfile" ,
    loader_cls= TextLoader,
    show_progress=False,
    loader_kwargs = {"encoding" : "utf-8"}
)

documents = load.load()
documents
# Out:
# [Document(metadata={'source': 'textfile\\text.txt'}, page_content='\nWastewater is used water that has been affected by human activities such as domestic, industrial, and agricultural use. It typically contains dissolved or suspended contaminants and must be treated before being released into the environment.\nWastewater treatment is the process of removing contaminants from wastewater to produce water that is safe for discharge or reuse. The process generally includes physical, biological, and chemical treatment stages.\nThe primary goal of wastewater management is to protect public health and the environment. Proper treatment reduces water pollution and helps maintain ecosystem balance.\nCommon sources of wastewater include households, factories, hospitals, and stormwater runoff. Each source contributes different types of pollutants that require specific treatment methods.\n'),
#  Document(metadata={'source': 'textfile\\text2.txt'}, page_content='Ma pagal hoo')]

# %%
from langchain_community.document_loaders import  PyMuPDFLoader

load = DirectoryLoader(
    "textfile" , 
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

documents = load.load()
documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 0}, page_content='TRIBHUVAN UNIVERSITY\nINSTITUTE OF ENGINEERING\nPASHCHIMANCHAL CAMPUS\nA Minor Project Report on\nProject Title\nSubmitted By:\nAananda Bastola\n[PAS079BCT002]\nAbhiujan Baral\n[PAS079BCT004]\nBishesh Tiwari\n[PAS079BCT013]\nSujal Luitel\n[PAS079BCT042]\nSubmitted To:\nDepartment of Electronics and Computer Engineering\nPashchimanchal Campus\nPokhara, Nepal\nJune 1, 2026'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 1}, page_content='ABSTRACT\nWater quality monitoring has become increasingly important due to a number of rea-\nsons, including the conservation of the environment, health security of humans, and\nregulation; however, conventional methods such as manual water sampling and sub-\nsequent laboratory tests have their limitations, which include high costs and delayed\nfeedbacks. The proposed research offers a solution to overcome the mentioned issues by\nproposing a machine learning-based IoT platform for the automated detection and clas-\nsification of any anomalies in the parameters of wastewater without human involvement\nand costly laboratory setup. Through use of ESP32-based microcontroller connected\nwith water quality sensors in the form of sensor nodes, and Raspberry Pi as the edge\ngateway, environmental parameters like pH level, turbidity, dissolved oxygen content,\ntemperature, electrical conductivity, and flow rate can be measured from different points\nof the wastewater treatment pipeline. As the parameters of the wastewater go out of\nthe normal operational range, different types of patterns emerge in the data obtained\nfrom the sensors that signify different kinds of anomalies.. The gathered sensor data is\ncleaned by filtering out any noise and normalizing the readings; subsequently, this data\nis grouped in intervals of time, and classification is performed using machine learning\nalgorithms such as Isolation Forest and LSTM Autoencoder for detecting anomalies\nand identifying patterns, respectively. The training dataset consists of labeled readings\ngathered during simulations in both real-world and simulated wastewater conditions at\ndifferent locations. The presented solution offers a cheaper, autonomous, and scalable\nreplacement to traditional systems of water quality control, facilitating the monitoring\nof continuously changing wastewater.\ni'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 2}, page_content='TABLE OF CONTENTS\nABSTRACT\n. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\ni\nLIST OF FIGURES . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\niii\nLIST OF TABLES . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\niv\nLIST OF ABBREVIATIONS . . . . . . . . . . . . . . . . . . . . . . . . . . .\nv\n1\nINTRODUCTION . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n1\n1.1\nBackground . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n1\n1.2\nProblem Statement\n. . . . . . . . . . . . . . . . . . . . . . . . . . . .\n2\n1.3\nObjectives . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n2\n1.4\nFeasibility Analysis . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n3\n1.4.1\nEconomic Feasibility Analysis . . . . . . . . . . . . . . . . . .\n3\n1.4.2\nTechnical Feasibility Analysis\n. . . . . . . . . . . . . . . . . .\n3\n1.4.3\nOperational Feasibility Analysis . . . . . . . . . . . . . . . . .\n3\n1.4.4\nLegal Feasibility Analysis\n. . . . . . . . . . . . . . . . . . . .\n4\n1.5\nScope of Project . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n4\n2\nLITERATURE REVIEW . . . . . . . . . . . . . . . . . . . . . . . . . . .\n5\n3\nREQUIREMENT ANALYSIS\n. . . . . . . . . . . . . . . . . . . . . . . .\n7\n3.1\nHardware Requirements . . . . . . . . . . . . . . . . . . . . . . . . . .\n7\n3.2\nSoftware Requirements . . . . . . . . . . . . . . . . . . . . . . . . . .\n7\n3.3\nFunctional Requirements . . . . . . . . . . . . . . . . . . . . . . . . .\n8\n3.4\nNon-functional Requirements . . . . . . . . . . . . . . . . . . . . . . .\n9\n4\nSYSTEM ARCHITECTURE AND METHODOLOGY\n. . . . . . . . . .\n10\n4.1\nTheoretical Background . . . . . . . . . . . . . . . . . . . . . . . . . .\n10\n4.2\nProject Development Life Cycle\n. . . . . . . . . . . . . . . . . . . . .\n10\n4.3\nArchitecture Used . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n10\n4.4\nUse Case Diagram . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n10\n4.5\nDFD Level-0 Diagram\n. . . . . . . . . . . . . . . . . . . . . . . . . .\n10\nREFERENCES . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n11\nii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 3}, page_content='LIST OF FIGURES\niii'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 4}, page_content='LIST OF TABLES\niv'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 5}, page_content='LIST OF ABBREVIATIONS\nABBR\nFull Form\nv'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 6}, page_content='CHAPTER 1\nINTRODUCTION\n1.1\nBackground\nOne of the most important concerns relating to environmental pollution and public health\nin the current century is the availability of good water and the efficient management of\nwaste water. Due to the fast pace of industrialization, urbanization, and development of\nagriculture, the amount and complexity of waste water being generated is on the rise.\nAs reported by UNEP, more than 80 percent of the total amount of waste water being\nproduced around the world goes into the environment without getting treated first, which\nleads to pollution of water and the spread of diseases caused by water.\nThe conventional means of conducting wastewater quality tests consist mainly of\nthe method of taking samples periodically, whereby water samples are drawn at regular\nintervals and sent to authorized labs for chemical and biological testing. Although the\ntechnique guarantees accuracy of testing, it is fundamentally flawed by its inherent in-\nfrequency and discreteness. Pollution peaks, machinery breakdowns, and unannounced\nchemical releases could take place and continue without being detected until the next\ntest period. This leads to considerable damage to the environment, which would have\nbeen impossible to rectify in time. Also, the expense incurred from using lab chemicals,\nqualified manpower, and transport is quite exorbitant to conduct such testing continu-\nously.\nWith the development of Internet of Things technology, revolutionary opportunities\nhave emerged for environmental monitoring. Such IoT-based sensor devices could be\nspread over multiple locations for monitoring crucial parameters of water quality like\npH, turbidity, total dissolved solids (TDS), and temperature. Smart sensors equipped\nwith low-cost microcontrollers like ESP32 exchange information through light-weight\ncommunication protocols like MQTT and forward the information to cloud servers.\nSuch an uninterrupted flow of data removes all temporal inconsistencies associated\nwith sampling and allows operators to address any anomaly quickly and efficiently, thus\ndecreasing risks associated with contaminations by several folds.\nNevertheless, the vast amounts of data generated by continuous sensor monitoring\nmake manual analysis inefficient and prone to error. Machine learning techniques pro-\nvide an effective solution by automatically learning normal wastewater behavior and\ndetecting abnormal conditions. Algorithms such as Isolation Forest can identify un-\nusual patterns in sensor readings without requiring labeled anomaly data, making them\nsuitable for real-time wastewater monitoring applications. Such anomalies may indi-\n1'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 7}, page_content='cate contamination events, unauthorized wastewater discharge, sudden environmental\nchanges, or sensor malfunctions.\nDespite all the advancements, the implementation of the smart wastewater quality\nmonitoring system will face several challenges, including the challenge of sensor drift,\nthe difficulty in providing a secure channel for communication inside underground\ninfrastructure, the problem of having no energy sources nearby the remote locations,\nand the lack of labeled datasets that can be used to train supervised learning models. In\norder to solve these problems, the proposed project will create a smart monitoring system\nfor wastewater, combining the IoT technology with ML methods. Using cheap sensors,\ncloud-based monitoring, and ML-based algorithms, this invention has the potential to\nbring wastewater monitoring into its next phase.\n1.2\nProblem Statement\nWater management is an important aspect when it comes to ensuring the safety of\nboth people and the environment; however, the methods that are employed by most\nwastewater treatment plants in measuring their water quality are old-fashioned and\nineffective.\nIn this case, water analysis relies mainly on water samples, which are\ncollected manually and analyzed in a lab, a method which is not only expensive but\nalso fails to give information about the water quality at any moment in time. As a\nresult, contamination events, unauthorized wastewater discharge, sudden changes in\nwater quality, and equipment failures may remain undetected until the next sampling\ncycle, potentially causing environmental damage and health risks.\nIt is on this basis that this research endeavors to bridge the gap by coming up with\nan affordable and intelligent wastewater quality monitoring system through IoT sensing\nnodes and machine learning algorithms for anomalies. This system will continuously\nmonitor the parameters of water quality in real time and thus ensure that any anomaly is\ndetected early enough and intervention measures are taken.\n1.3\nObjectives\ni. Deploy an IoT Sensor Network: To build and deploy low-cost ESP32-based\nsensor nodes that continuously measure wastewater quality parameters including\npH, turbidity,turbidity, total dissolved solids (TDS), and temperature in real time.\nii. Detect Anomalies Using Machine Learning: To develop and integrate an Iso-\nlation Forest model capable of autonomously identifying contamination events,\nabnormal patterns, and equipment failures from real-time sensor data.\niii. Deliver Real-Time Monitoring and Alerts: To create a web-based dashboard\n2'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 8}, page_content='with live data visualization and automated alerts that empower operators to re-\nspond proactively to water quality threats and maintain regulatory compliance.\n1.4\nFeasibility Analysis\nA feasibility analysis has been performed in order to analyze the practicality of design-\ning, constructing, and operating the IoT-driven water quality monitoring and anomaly\ndetection system for wastewater. There are four main areas that are assessed in the\nfeasibility study in terms of viability; namely technical feasibility, economic feasibility,\noperational feasibility, and legal feasibility.\n1.4.1\nEconomic Feasibility Analysis\nThis system will be entirely built using low-cost hardware parts available in the local\nmarket, making it cost-effective compared to any commercial water quality monitoring\nsystem. All the software programs used such as Python, Flask, Scikit-learn, PostgreSQL,\nand VS Code will be totally free of charge and open source, which means that there will\nbe no need for paying any licensing fees. Amazon Web Services EC2 has a free tier that\nwill serve well in the current project, and thus hosting charges will not be required at all.\n1.4.2\nTechnical Feasibility Analysis\nAll technologies utilized in this project are thoroughly tested and accessible to everyone.\nThere will be no need for any additional processor as the ESP32 microcontroller can\nsimultaneously process multiple sensor inputs and send messages via MQTT over WiFi.\nAll sensors used in this solution – pH, turbidity, TDS sensor, and DS18B20 – work\nperfectly with ESP32 and have respective Arduino libraries. On the software side, the\nchosen programming languages are all mature and well-documented and thus are easily\nmanageable even by a small group of developers. Amazon Web Services EC2 is also a\ngood choice for setting up the server, database, and anomaly detection service because\nof the great reliability of their cloud infrastructure.\n1.4.3\nOperational Feasibility Analysis\nOnce the system is installed, it operates continuously without needing human assistance.\nData sensing, communication, storage, and analysis are all done automatically, thus\nmaking life easier for the operators at the plant site by saving them from routine activities.\nThe web-based interface of the system is very easy to use, and no special technical\nexpertise is needed to access it, which means that even nontechnical people can use it.\nAlerts are automatically sent to the operator whenever the system detects any anomaly\nin the system. Moreover, there are no problems in carrying out maintenance work due\n3'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 9}, page_content='to the presence of generic parts in the system.\n1.4.4\nLegal Feasibility Analysis\nThe system will not be storing, collecting, or processing any personally identifiable\ninformation, which means that there will be no issues regarding data protection laws\napplicable to this project, thus, rendering the system safe from such legal risks. All soft-\nware systems used are based on open source frameworks and are distributed according\nto open source license agreements, which excludes any potential issues with licensing\nor intellectual property. Data kept in the AWS EC2 server will also be subject to com-\npliance framework of Amazon, adding an extra layer of legal and security compliance.\nFinally, the purpose of the system makes it environmentally compliant since it monitors\nthe existing environmental protection standards.\n1.5\nScope of Project\n• The monitoring system is to be implemented by tracking vital quality parameters of\nthe wastewater such as pH, turbidity, total dissolved solids (TDS) and temperature\nthrough sensors with the help of ESP32 microcontroller.\n• Sensor data will be transmitted wirelessly through Wi-Fi and stored in a cloud-\nbased database.\n• Isolation Forest models of machine learning will be applied for automatic anomaly\ndetection.\n• Real-time visualization of the data in the form of a dashboard shall be provided\nin order to track anomalies and visualize the sensor measurements.\n• System design, implementation, testing, and evaluation are going to take place in\nthe lab setting that simulates wastewater monitoring conditions.\n• However, industrial-scale installation, chemical treatment processes, and integra-\ntion with a SCADA system used in municipal facilities do not belong to the scope\nof work.\n4'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 10}, page_content='CHAPTER 2\nLITERATURE REVIEW\nEssamlali et al. [1] provided a thorough review on IoT and ML-based methods used\nin areas of water quality monitoring (WQM). They studied several IoT architectures,\nwater quality parameters, and ML algorithms for water monitoring and quality predic-\ntion. Their review highlighted that IoT sensors enable the gathering and analysis of\nvast amounts of data on WQ, facilitating the creation of accurate and reliable models\nfor forecasting WQ, while application of ML algorithms in WQM has enhanced the\nefficiency of WQM, analysis, and prediction, ensuring real-time analysis and anomaly\ndetection in water quality assessment. This study can be viewed as a theoretical review\npaper without providing any solutions for developing an entire low-cost monitoring\nsystem based on IoT and ML technology.\nSalem et al. [2] proposed an IoT cloud wastewater monitoring system and evaluated\nthe proposed system in the C9 Wastewater Treatment Plant of Egypt.\nThe system\ncollected pH and temperature sensor data using ESP8266 module from the site every 15\nminutes with real-time monitoring in dashboards that were updated every five seconds.\nIt was experimentally observed that abnormal pH levels readings at the pumping station\ngot transmitted to the wastewater treatment plant within 30 minutes, enabling prompt\naction to be taken without causing any damage. However,this suggested approach was\nbased on threshold monitoring systems and did not consider machine learning-based\ntechniques that could help detect anomalies or predict future conditions in wastewater\nsystems.\nPrasad et al. [3] suggested a machine learning and AutoML solution for automatic\nevaluation of water quality based on data obtained from Korattur Lake in India. In\nthe study, water quality attributes, like pH, turbidity, TDS, COD, nitrate, phosphate,\nsodium, chloride, and iron were used as input data for water quality classification. The\nresults revealed that, compared to the application of classical machine learning methods,\nAutoML attained about 1.4% greater accuracy in binary classification and somewhat\nhigher accuracy in multiclass classification. The results proved that machine learning\nis an efficient tool in water quality classification. Nevertheless, the study used only\nhistorical data and did not consider IoT sensors.\nGhinea et al. [4] explored the use of various semi-supervised machine learning\napproaches to detect anomalies in wastewater treatment plants. The authors compared\nIsolation Forest (IF), Local Outlier Factor (LOF), One-Class Support Vector Machine\n(OCSVM), Multilayer Perceptron Autoencoder (MLP-AE), and Convolutional Autoen-\n5'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 11}, page_content='coder (Conv-AE) to analyze anomalies in dissolved oxygen sensors and aeration valves.\nThe authors found that Conv-AE produced the highest accuracies for detecting anoma-\nlies of 98.36%, 97.81%, and 98.64% in the case of complete, concurrent, and complex\nfault conditions, respectively. Furthermore, the researchers found that Isolation Forest\ncan be used to successfully detect abnormal sensor behavior even without training using\nlabeled anomalous data. As such, Isolation Forest proved to be an effective and computa-\ntionally efficient approach for anomaly detection in wastewater treatment. However, the\nresearch did not consider low-cost IoT-based sensor application for real-time monitoring\nof wastewater quality.\nAn IoT-based low-cost water quality monitoring framework was proposed by Pokhrel\net al. [5], involving ESP32, pH, and conductivity sensors for the real-time assessment\nof water quality. The collected information was then sent to a web server for storage and\nfurther monitoring. Experimental results indicated that the developed framework had an\nerror rate of 2.85% in the pH sensor and 5.6% in the conductivity sensor, suggesting a\ndecent level of accuracy in monitoring the water quality. It was clear from the work that\nIoT can be used effectively for assessing the water quality in Nepal at an affordable cost.\nHowever, the proposed system relied on threshold-based monitoring and not machine\nlearning techniques for anomaly detection or predictive analysis.\nThe studies reviewed above have shown that IoT technologies offer an efficient means\nof performing real-time monitoring of water quality, and machine learning technologies\nenhance their abilities for classifying and detecting anomalies.\nHowever, previous\nresearches have either addressed the problem of using IoT for monitoring purposes\nwithout considering any intelligent analyses or applied machine learning algorithms\nbased on historical data, but not on real-time data coming from sensors. Moreover, no\nattempts have been made to use IoT devices along with machine learning models of\ndetecting anomalies in wastewater quality monitoring. This work suggests developing\na system for monitoring and detecting anomalies in wastewater using IoT and machine\nlearning technologies.\n6'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 12}, page_content='CHAPTER 3\nREQUIREMENT ANALYSIS\n3.1\nHardware Requirements\n• ESP32 Dev Board — A low-cost, Wi-Fi-enabled microcontroller that serves as the\nbrain of the system, responsible for reading all connected sensors and transmitting\ndata wirelessly to the cloud via MQTT.\n• pH Sensor Module — Measures the acidity or alkalinity of wastewater, providing\none of the most critical indicators of water quality and chemical contamination\nlevels.\n• Turbidity Sensor — Detects the cloudiness of water caused by suspended parti-\ncles, offering a direct measure of water clarity and pollution levels.\n• TDS Sensor — Measures the concentration of total dissolved solids in the water,\nindicating the presence of contaminants, salts, and other dissolved substances.\n• DS18B20 Waterproof Temperature Sensor — A waterproof digital probe that\ncontinuously monitors water temperature, which is an important parameter influ-\nencing chemical and biological processes in wastewater.\n• Breadboard and Jumper Wires — Used during the prototyping phase to connect\nand test all sensor modules with the ESP32 without the need for soldering.\n• 5V Power Adapter / Power Bank — Provides a stable and consistent power\nsupply to the ESP32 and all connected sensors throughout system operation.\n• Waterproof Project Box — A protective enclosure that houses the ESP32 and\ncircuit components, shielding them from moisture and physical damage during\ndeployment.\n• Wi-Fi Router — Provides the local wireless network through which the ESP32\nconnects to the internet and transmits sensor data to the cloud platform.\n3.2\nSoftware Requirements\n• Arduino IDE — Used to write and upload firmware onto the ESP32 dev board. It\nhas built-in support for ESP32 board configurations and sensor libraries, making\nit the right tool for programming the device and managing sensor reading and\nMQTT transmission logic.\n• Python 3.x — The main programming language used throughout this project for\nbackend development, sensor data processing, anomaly detection model training,\nand tying all the different system components together into one working pipeline.\n• Visual Studio Code — The primary code editor used for writing and debugging\n7'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 13}, page_content='the Flask backend, Python scripts, and dashboard code.\nIts Python and Git\nextension support makes everyday development work faster and more manageable.\n• Git / GitHub — Used to track and manage all project code from ESP32 firmware\nto the web dashboard. It keeps the codebase organized and makes collaboration\nbetween team members straightforward throughout the project.\n• AWS EC2 — Hosts the Flask server, PostgreSQL database, and anomaly detection\nmodel on the cloud, allowing the ESP32 to send data remotely and giving operators\naccess to the live dashboard from any browser at any time.\n• PostgreSQL / MySQL — Stores all sensor readings received from the ESP32\nalongside anomaly records and alert history, supporting historical data queries,\ntrend monitoring, and report generation as needed.\n• Flask — Used to build the backend API that receives sensor data, saves it to the\ndatabase, runs anomaly detection, and serves the real-time monitoring dashboard\nto operators through a browser.\n• Scikit-learn — Used to implement the Isolation Forest model that continuously\nanalyzes incoming sensor data and flags abnormal readings such as contamination\nspikes, sudden parameter shifts, or sensor irregularities as they happen.\n3.3\nFunctional Requirements\n• Sensor Data Collection — The system shall read the signals of TDS, pH, turbidity,\nand temperature sensors that are connected to the ESP32 dev board continuously\nat certain time intervals.\n• Wireless Data Transmission — The ESP32 will transmit all sensor data wire-\nlessly over Wi-Fi to the Flask backend hosted on AWS EC2 via the MQTT\nprotocol.\n• Data Storage — The Flask backend will take incoming sensor data and log\nall measurements with timestamps, parameter values, and sensor labels to the\nPostgreSQL database on EC2 for record keeping.\n• Anomaly Detection — The system will automatically run the Isolation Forest\nmodel on new sensor data in order to detect anomalies, contamination events, and\nunusual parameter trends without operator intervention.\n• Real-Time Alert Generation — The system shall issue automated alerts on\nthe dashboard if an anomaly detection model finds a reading abnormal so that\noperators are informed promptly and can take necessary corrective action.\n• Real-Time Dashboard — The Flask web application shall serve a user interface\naccessible through a web browser that presents operators with real-time sensor\ndata, current water quality status, anomaly notifications, and historical trends in a\nuser-friendly manner.\n8'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 14}, page_content='• Historical Data Query — The system shall give operators access to historical\nsensor readings and past anomalies observed in the PostgreSQL database for trend\nanalysis, status analysis, operational issue analysis, and compliance documenta-\ntion.\n3.4\nNon-functional Requirements\n• Reliability — The system shall remain operational at all times, capturing sensor\ninformation, transmitting data, and taking all required actions during anticipated\nnormal events.\n• Real-Time Performance — The system shall process received sensor data and\nreflect it on the dashboard with minimum latency so that operators can see the\nmost recent water quality readings and anomaly status at any time.\n• Scalability — The backend system running on the AWS EC2 platform shall be\nflexible enough to include future sensor nodes and manage future data volumes\nwithout any major change in the system design.\n• Usability — The web dashboard will be straightforward, clean, and intuitive\nenough for non-technical plant operators to understand and operate without any\nspecial training or technical knowledge.\n• Security — Data transmitted between the ESP32 and the AWS EC2 backend shall\nbe handled securely, and unauthorized access to the dashboard and database shall\nbe prevented to protect sensor records.\n• Maintainability — The system code shall be kept in a clean, well-documented,\nand modular form so that the firmware, backend, machine learning model, and\ndashboard can be updated or debugged individually.\n• Portability — The hardware setup shall be designed to be compact enough to fit\nwithin the waterproof project box and run at various monitoring locations without\nrequiring major alteration or additional infrastructure.\n9'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 15}, page_content='CHAPTER 4\nSYSTEM ARCHITECTURE AND METHODOLOGY\n4.1\nTheoretical Background\nThis project bridges the gap between traditional, inefficient water testing and modern\nenvironmental management by integrating Internet of Things (IoT) sensing with Machine\nLearning (ML).\n• IoT Sensing Layer: The system utilizes ESP32 microcontrollers to continuously\ntrack vital water quality parameters—specifically pH, turbidity, total dissolved\nsolids (TDS), and temperature. This replaces infrequent, manual, and discrete\nlaboratory sampling with a continuous, real-time data stream transmitted via Wi-\nFi.\n• Machine Learning Analytics: To process the vast volume of sensor data effec-\ntively, the Isolation Forest algorithm is employed. As an unsupervised learning\ntechnique, it autonomously identifies "normal" wastewater behavior and flags\nanomalies without the need for pre-labeled datasets.\n• Operational Impact: The synergy between real-time sensing and predictive\nanalytics enables the early detection of contamination events, unauthorized dis-\ncharges, and sensor malfunctions. This empowers operators to initiate proactive\ninterventions via a centralized web dashboard, significantly reducing environmen-\ntal and health risks.\n4.2\nProject Development Life Cycle\n4.3\nArchitecture Used\n4.4\nUse Case Diagram\n4.5\nDFD Level-0 Diagram\n10'),
#  Document(metadata={'producer': 'pdfTeX-1.40.28', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-05-31T16:05:33+00:00', 'source': 'textfile\\main.pdf', 'file_path': 'textfile\\main.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-05-31T16:05:33+00:00', 'trapped': '', 'modDate': 'D:20260531160533Z', 'creationDate': 'D:20260531160533Z', 'page': 16}, page_content='REFERENCES\n[1] I. Essamlali, H. Nhaila, and M. El Khaili, “Advances in Machine Learning and IoT\nfor Water Quality Monitoring: A Comprehensive Review,” Heliyon, vol. 10, no. 6,\nArt. no. e27920, 2024, doi: 10.1016/j.heliyon.2024.e27920.\n[2] R. M. M. Salem, M. S. Saraya, and A. M. T. Ali-Eldin, “An Industrial Cloud-\nBased IoT System for Real-Time Monitoring and Controlling of Wastewater,” IEEE\nAccess, vol. 10, pp. 6528–6540, 2022, doi: 10.1109/ACCESS.2022.3141977.\n[3] D. V. V. Prasad, P. Senthil Kumar, L. Y. Venkataramana, G. Prasannamedha,\nS. Harshana, S. J. Srividya, K. Harrinei, and S. Indraganti, “Automating Water\nQuality Analysis Using ML and Auto ML Techniques,” Environmental Research,\nvol. 202, Art. no. 111720, 2021, doi: 10.1016/j.envres.2021.111720.\n[4] L. M. Ghinea, M. Miron, and M. Barbu, “Semi-Supervised Anomaly Detection of\nDissolved Oxygen Sensor in Wastewater Treatment Plants,” Sensors, vol. 23, no.\n19, Art. no. 8022, 2023, doi: 10.3390/s23198022.\n[5] S. Pokhrel, A. Pant, R. Gautam, and D. B. Kshatri, “Water Quality Monitoring\nSystem Using IoT,” Journal of Innovations in Engineering Education, vol. 3, no.\n1, pp. 155–164, 2020.\n11')]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'
